# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('../data/train.csv')
df.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12                1824.84                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12                1824.84                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                    26.82  22 Years and 1 Months
# 1            809.98                    31.94                    NaN
# 2            809.98                    28.61  22 Years and 3 Months
# 3            809.98                    31.38  22 Years and 4 Months
# 4            809.98                    24.80  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No               49.57       80.41529543900253
# 1                     No               49.57      118.28022162236736
# 2                     No               49.57         81.699521264648
# 3                     No               49.57       199.4580743910713
# 4                     No               49.57      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count               84998.00          100000.00        100000.00
# mean                 4194.17              17.09            22.47
# std                  3183.69             117.40           129.06
# min                   303.65              -1.00             0.00
# 25%                  1625.57               3.00             4.00
# 50%                  3093.75               6.00             5.00
# 75%                  5957.45               7.00             7.00
# max                 15204.63            1798.00          1499.00
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count      100000.00            100000.00              98035.00
# mean           72.47                21.07                 27.75
# std           466.42                14.86                193.18
# min             1.00                -5.00                  0.00
# 25%             8.00                10.00                  3.00
# 50%            13.00                18.00                  6.00
# 75%            20.00                28.00                  9.00
# max          5797.00                67.00               2597.00
#
#        Credit_Utilization_Ratio  Total_EMI_per_month
# count                 100000.00            100000.00
# mean                      32.29              1403.12
# std                        5.12              8306.04
# min                       20.00                 0.00
# 25%                       28.05                30.31
# 50%                       32.31                69.25
# 75%                       36.50               161.22
# max                       50.00             82331.00

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# dtype: object

# %%
#Drop the column which is out of model scope
d_col = ['ID','Customer_ID','Month','Name','SSN','Monthly_Inhand_Salary','Num_Bank_Accounts','Num_Credit_Card',
         'Interest_Rate','Num_of_Loan','Type_of_Loan','Changed_Credit_Limit','Num_Credit_Inquiries','Credit_Mix',
         'Credit_Utilization_Ratio','Amount_invested_monthly']
drop_df = df.drop(d_col , axis=1).copy()
drop_df
# Out:
#         Age Occupation Annual_Income  Delay_from_due_date  \
# 0        23  Scientist      19114.12                    3
# 1        23  Scientist      19114.12                   -1
# 2      -500  Scientist      19114.12                    3
# 3        23  Scientist      19114.12                    5
# 4        23  Scientist      19114.12                    6
# ...     ...        ...           ...                  ...
# 99995    25   Mechanic      39628.99                   23
# 99996    25   Mechanic      39628.99                   18
# 99997    25   Mechanic      39628.99                   27
# 99998    25   Mechanic      39628.99                   20
# 99999    25   Mechanic     39628.99_                   18
#
#       Num_of_Delayed_Payment Outstanding_Debt      Credit_History_Age  \
# 0                          7           809.98   22 Years and 1 Months
# 1                        NaN           809.98                     NaN
# 2                          7           809.98   22 Years and 3 Months
# 3                          4           809.98   22 Years and 4 Months
# 4                        NaN           809.98   22 Years and 5 Months
# ...                      ...              ...                     ...
# 99995                      7           502.38   31 Years and 6 Months
# 99996                      7           502.38   31 Years and 7 Months
# 99997                      6           502.38   31 Years and 8 Months
# 99998                    NaN           502.38   31 Years and 9 Months
# 99999                      6           502.38  31 Years and 10 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                        No                49.57
# 1                        No                49.57
# 2                        No                49.57
# 3                        No                49.57
# 4                        No                49.57
# ...                     ...                  ...
# 99995                    No                35.10
# 99996                    No                35.10
# 99997                    No                35.10
# 99998                    No                35.10
# 99999                    No                35.10
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score
# 0       High_spent_Small_value_payments  312.49408867943663         Good
# 1        Low_spent_Large_value_payments  284.62916249607184         Good
# 2       Low_spent_Medium_value_payments   331.2098628537912         Good
# 3        Low_spent_Small_value_payments  223.45130972736786         Good
# 4      High_spent_Medium_value_payments  341.48923103222177         Good
# ...                                 ...                 ...          ...
# 99995   High_spent_Large_value_payments              479.87         Poor
# 99996  High_spent_Medium_value_payments              496.65         Poor
# 99997   High_spent_Large_value_payments              516.81         Poor
# 99998    Low_spent_Large_value_payments              319.16     Standard
# 99999                            !@9#%8              393.67         Poor
#
# [100000 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
#Drop it
drop_na = drop_df.dropna().copy()

# %%
#Drop the incorrect data
df = df[df['Occupation'].str.contains('_______') == False]
df = df[df['Payment_Behaviour'].str.contains('!@9#%8') == False]

# %%
#Drop the incorrect data
drop_na = drop_na[drop_na['Occupation'].str.contains('_______') == False]
drop_na = drop_na[drop_na['Payment_Behaviour'].str.contains('!@9#%8') == False]

# %%
# Revise the incorrect data whole table
sym = "\\`*_{}[]()>#@+!$:;"
col_int = ['Age','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt',
           'Total_EMI_per_month','Monthly_Balance','Annual_Income']
col_str = ['Occupation','Credit_History_Age','Payment_of_Min_Amount','Credit_Score']
for i in col_int:
  for c in sym:
    drop_na[i] = drop_na[i].astype(str).str.replace(c,'')
for i in col_str:
  for c in sym:
    drop_na[i] = drop_na[i].replace(c,'')
drop_na.head()
# Out:
#     Age Occupation Annual_Income Delay_from_due_date Num_of_Delayed_Payment  \
# 0    23  Scientist      19114.12                   3                      7
# 2  -500  Scientist      19114.12                   3                      7
# 3    23  Scientist      19114.12                   5                      4
# 6    23  Scientist      19114.12                   3                      8
# 9    28    Teacher      34847.84                   7                      1
#
#   Outstanding_Debt     Credit_History_Age Payment_of_Min_Amount  \
# 0           809.98  22 Years and 1 Months                    No
# 2           809.98  22 Years and 3 Months                    No
# 3           809.98  22 Years and 4 Months                    No
# 6           809.98  22 Years and 7 Months                    No
# 9           605.03  26 Years and 8 Months                    No
#
#   Total_EMI_per_month                Payment_Behaviour     Monthly_Balance  \
# 0   49.57494921489417  High_spent_Small_value_payments  312.49408867943663
# 2   49.57494921489417  Low_spent_Medium_value_payments   331.2098628537912
# 3   49.57494921489417   Low_spent_Small_value_payments  223.45130972736786
# 6   49.57494921489417   Low_spent_Small_value_payments   244.5653167062043
# 9  18.816214573128885  High_spent_Large_value_payments   484.5912142650067
#
#   Credit_Score
# 0         Good
# 2         Good
# 3         Good
# 6         Good
# 9         Good

# %%
#Transform the information to the value
drop_na['Credit_History_Age'] = drop_na['Credit_History_Age'].astype(str).str.replace(' Years and ','.')
drop_na['Credit_History_Age'] = drop_na['Credit_History_Age'].astype(str).str.replace('Months','')

# %%
#Transform the information to the value as level
drop_na['Payment_Behaviour'] = drop_na['Payment_Behaviour'].astype(str).str.replace('Low_spent_Small_value_payments','1')
drop_na['Payment_Behaviour'] = drop_na['Payment_Behaviour'].astype(str).str.replace('Low_spent_Medium_value_payments','2')
drop_na['Payment_Behaviour'] = drop_na['Payment_Behaviour'].astype(str).str.replace('Low_spent_Large_value_payments','3')
drop_na['Payment_Behaviour'] = drop_na['Payment_Behaviour'].astype(str).str.replace('High_spent_Small_value_payments','4')
drop_na['Payment_Behaviour'] = drop_na['Payment_Behaviour'].astype(str).str.replace('High_spent_Medium_value_payments','5')
drop_na['Payment_Behaviour'] = drop_na['Payment_Behaviour'].astype(str).str.replace('High_spent_Large_value_payments','6')
drop_na.head()
# Out:
#     Age Occupation Annual_Income Delay_from_due_date Num_of_Delayed_Payment  \
# 0    23  Scientist      19114.12                   3                      7
# 2  -500  Scientist      19114.12                   3                      7
# 3    23  Scientist      19114.12                   5                      4
# 6    23  Scientist      19114.12                   3                      8
# 9    28    Teacher      34847.84                   7                      1
#
#   Outstanding_Debt Credit_History_Age Payment_of_Min_Amount  \
# 0           809.98              22.1                     No
# 2           809.98              22.3                     No
# 3           809.98              22.4                     No
# 6           809.98              22.7                     No
# 9           605.03              26.8                     No
#
#   Total_EMI_per_month Payment_Behaviour     Monthly_Balance Credit_Score
# 0   49.57494921489417                 4  312.49408867943663         Good
# 2   49.57494921489417                 2   331.2098628537912         Good
# 3   49.57494921489417                 1  223.45130972736786         Good
# 6   49.57494921489417                 1   244.5653167062043         Good
# 9  18.816214573128885                 6   484.5912142650067         Good

# %%
#Transform the object data the be float data type 
col_int2 = ['Age','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt',
            'Total_EMI_per_month','Monthly_Balance','Payment_Behaviour','Credit_History_Age','Annual_Income']
for i in col_int2:
  drop_na[i] = drop_na[i].astype(float)
drop_na.dtypes
# Out:
# Age                       float64
# Occupation                 object
# Annual_Income             float64
# Delay_from_due_date       float64
# Num_of_Delayed_Payment    float64
# Outstanding_Debt          float64
# Credit_History_Age        float64
# Payment_of_Min_Amount      object
# Total_EMI_per_month       float64
# Payment_Behaviour         float64
# Monthly_Balance           float64
# Credit_Score               object
# dtype: object

# %%
# Transform the target data to numerical
drop_na['Credit_Score'] = drop_na['Credit_Score'].str.replace('Good', '3', n=-1)
drop_na['Credit_Score'] = drop_na['Credit_Score'].str.replace('Standard', '2', n=-1)
drop_na['Credit_Score'] = drop_na['Credit_Score'].str.replace('Poor', '1', n=-1)
drop_na['Credit_Score'] = drop_na[['Credit_Score']].apply(pd.to_numeric)

drop_na['Payment_of_Min_Amount'] = drop_na['Payment_of_Min_Amount'].str.replace('NM', '0')
drop_na['Payment_of_Min_Amount'] = drop_na['Payment_of_Min_Amount'].str.replace('Yes', '1')
drop_na['Payment_of_Min_Amount'] = drop_na['Payment_of_Min_Amount'].str.replace('No', '2')
drop_na['Payment_of_Min_Amount'] = drop_na[['Payment_of_Min_Amount']].apply(pd.to_numeric)
drop_na
# Out:
#           Age Occupation  Annual_Income  Delay_from_due_date  \
# 0       23.00  Scientist       19114.12                 3.00
# 2     -500.00  Scientist       19114.12                 3.00
# 3       23.00  Scientist       19114.12                 5.00
# 6       23.00  Scientist       19114.12                 3.00
# 9       28.00    Teacher       34847.84                 7.00
# ...       ...        ...            ...                  ...
# 99991   29.00  Architect       20002.88                33.00
# 99994   25.00   Mechanic       39628.99                20.00
# 99995   25.00   Mechanic       39628.99                23.00
# 99996   25.00   Mechanic       39628.99                18.00
# 99997   25.00   Mechanic       39628.99                27.00
#
#        Num_of_Delayed_Payment  Outstanding_Debt  Credit_History_Age  \
# 0                        7.00            809.98               22.10
# 2                        7.00            809.98               22.30
# 3                        4.00            809.98               22.40
# 6                        8.00            809.98               22.70
# 9                        1.00            605.03               26.80
# ...                       ...               ...                 ...
# 99991                   25.00           3571.70                6.30
# 99994                    6.00            502.38               31.50
# 99995                    7.00            502.38               31.60
# 99996                    7.00            502.38               31.70
# 99997                    6.00            502.38               31.80
#
#        Payment_of_Min_Amount  Total_EMI_per_month  Payment_Behaviour  \
# 0                          2                49.57               4.00
# 2                          2                49.57               2.00
# 3                          2                49.57               1.00
# 6                          2                49.57               1.00
# 9                          2                18.82               6.00
# ...                      ...                  ...                ...
# 99991                      1                60.96               6.00
# 99994                      2                35.10               5.00
# 99995                      2                35.10               6.00
# 99996                      2                35.10               5.00
# 99997                      2                35.10               6.00
#
#        Monthly_Balance  Credit_Score
# 0               312.49             3
# 2               331.21             3
# 3               223.45             3
# 6               244.57             3
# 9               484.59             3
# ...                ...           ...
# 99991           337.36             2
# 99994           410.26             1
# 99995           479.87             1
# 99996           496.65             1
# 99997           516.81             1
#
# [71843 rows x 12 columns]

# %%
drop_na.dtypes
# Out:
# Age                       float64
# Occupation                 object
# Annual_Income             float64
# Delay_from_due_date       float64
# Num_of_Delayed_Payment    float64
# Outstanding_Debt          float64
# Credit_History_Age        float64
# Payment_of_Min_Amount       int64
# Total_EMI_per_month       float64
# Payment_Behaviour         float64
# Monthly_Balance           float64
# Credit_Score                int64
# dtype: object

# %%
drop_na.count()
# Out:
# Age                       71843
# Occupation                71843
# Annual_Income             71843
# Delay_from_due_date       71843
# Num_of_Delayed_Payment    71843
# Outstanding_Debt          71843
# Credit_History_Age        71843
# Payment_of_Min_Amount     71843
# Total_EMI_per_month       71843
# Payment_Behaviour         71843
# Monthly_Balance           71843
# Credit_Score              71843
# dtype: int64

# %%
drop_na = drop_na.drop_duplicates()
drop_na.count()
# Out:
# Age                       71843
# Occupation                71843
# Annual_Income             71843
# Delay_from_due_date       71843
# Num_of_Delayed_Payment    71843
# Outstanding_Debt          71843
# Credit_History_Age        71843
# Payment_of_Min_Amount     71843
# Total_EMI_per_month       71843
# Payment_Behaviour         71843
# Monthly_Balance           71843
# Credit_Score              71843
# dtype: int64

# %%
drop_na.head()
# Out:
#       Age Occupation  Annual_Income  Delay_from_due_date  \
# 0   23.00  Scientist       19114.12                 3.00
# 2 -500.00  Scientist       19114.12                 3.00
# 3   23.00  Scientist       19114.12                 5.00
# 6   23.00  Scientist       19114.12                 3.00
# 9   28.00    Teacher       34847.84                 7.00
#
#    Num_of_Delayed_Payment  Outstanding_Debt  Credit_History_Age  \
# 0                    7.00            809.98               22.10
# 2                    7.00            809.98               22.30
# 3                    4.00            809.98               22.40
# 6                    8.00            809.98               22.70
# 9                    1.00            605.03               26.80
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Payment_Behaviour  \
# 0                      2                49.57               4.00
# 2                      2                49.57               2.00
# 3                      2                49.57               1.00
# 6                      2                49.57               1.00
# 9                      2                18.82               6.00
#
#    Monthly_Balance  Credit_Score
# 0           312.49             3
# 2           331.21             3
# 3           223.45             3
# 6           244.57             3
# 9           484.59             3

# %%
df_cleaned = drop_na

# %%
df_cleaned.describe()
# Out:
#            Age  Annual_Income  Delay_from_due_date  Num_of_Delayed_Payment  \
# count 71843.00       71843.00             71843.00                71843.00
# mean    110.77      175118.26                21.04                   31.19
# std     685.33     1430392.46                14.87                  228.22
# min    -500.00        7005.93                -5.00                   -3.00
# 25%      24.00       19307.90                10.00                    9.00
# 50%      33.00       36966.76                18.00                   14.00
# 75%      42.00       72305.90                28.00                   18.00
# max    8698.00    24198062.00                67.00                 4397.00
#
#        Outstanding_Debt  Credit_History_Age  Payment_of_Min_Amount  \
# count          71843.00            71843.00               71843.00
# mean            1422.21               18.39                   1.24
# std             1151.14                8.29                   0.65
# min                0.23                0.10                   0.00
# 25%              566.00               12.10                   1.00
# 50%             1163.40               18.20                   1.00
# 75%             1941.54               25.10                   2.00
# max             4998.07               33.80                   2.00
#
#        Total_EMI_per_month  Payment_Behaviour                 Monthly_Balance  \
# count             71843.00           71843.00                        71843.00
# mean               1400.98               3.27     -32478227987880977891328.00
# std                8279.35               1.85    3290162889409645544210432.00
# min                   0.00               1.00 -333333333333333314856026112.00
# 25%                  30.12               1.00                          269.83
# 50%                  68.35               3.00                          336.41
# 75%                 156.47               5.00                          470.90
# max               82331.00               6.00                         1602.04
#
#        Credit_Score
# count      71843.00
# mean           1.89
# std            0.68
# min            1.00
# 25%            1.00
# 50%            2.00
# 75%            2.00
# max            3.00

# %%
# Drop outlier by IQR calculation
Q1 = df_cleaned.Annual_Income.quantile(0.25)
Q3 = df_cleaned.Annual_Income.quantile(0.75)
IQR = Q3 - Q1
df_cleaned = df_cleaned.drop(df_cleaned.loc[df_cleaned['Annual_Income'] > (Q3 + 1.5 * IQR)].index)
df_cleaned = df_cleaned.drop(df_cleaned.loc[df_cleaned['Annual_Income'] < (Q1 - 1.5 * IQR)].index)
df_cleaned
# Out:
#           Age Occupation  Annual_Income  Delay_from_due_date  \
# 0       23.00  Scientist       19114.12                 3.00
# 2     -500.00  Scientist       19114.12                 3.00
# 3       23.00  Scientist       19114.12                 5.00
# 6       23.00  Scientist       19114.12                 3.00
# 9       28.00    Teacher       34847.84                 7.00
# ...       ...        ...            ...                  ...
# 99991   29.00  Architect       20002.88                33.00
# 99994   25.00   Mechanic       39628.99                20.00
# 99995   25.00   Mechanic       39628.99                23.00
# 99996   25.00   Mechanic       39628.99                18.00
# 99997   25.00   Mechanic       39628.99                27.00
#
#        Num_of_Delayed_Payment  Outstanding_Debt  Credit_History_Age  \
# 0                        7.00            809.98               22.10
# 2                        7.00            809.98               22.30
# 3                        4.00            809.98               22.40
# 6                        8.00            809.98               22.70
# 9                        1.00            605.03               26.80
# ...                       ...               ...                 ...
# 99991                   25.00           3571.70                6.30
# 99994                    6.00            502.38               31.50
# 99995                    7.00            502.38               31.60
# 99996                    7.00            502.38               31.70
# 99997                    6.00            502.38               31.80
#
#        Payment_of_Min_Amount  Total_EMI_per_month  Payment_Behaviour  \
# 0                          2                49.57               4.00
# 2                          2                49.57               2.00
# 3                          2                49.57               1.00
# 6                          2                49.57               1.00
# 9                          2                18.82               6.00
# ...                      ...                  ...                ...
# 99991                      1                60.96               6.00
# 99994                      2                35.10               5.00
# 99995                      2                35.10               6.00
# 99996                      2                35.10               5.00
# 99997                      2                35.10               6.00
#
#        Monthly_Balance  Credit_Score
# 0               312.49             3
# 2               331.21             3
# 3               223.45             3
# 6               244.57             3
# 9               484.59             3
# ...                ...           ...
# 99991           337.36             2
# 99994           410.26             1
# 99995           479.87             1
# 99996           496.65             1
# 99997           516.81             1
#
# [69840 rows x 12 columns]

# %%
### Balancing - Occupation
occupation_count = df_cleaned['Occupation'].value_counts(dropna = False)
occupation_count
# Out:
# Lawyer           4912
# Mechanic         4761
# Teacher          4760
# Engineer         4752
# Architect        4735
# Scientist        4722
# Entrepreneur     4680
# Developer        4659
# Media_Manager    4651
# Accountant       4647
# Journalist       4614
# Doctor           4580
# Manager          4480
# Musician         4473
# Writer           4414
# Name: Occupation, dtype: int64

# %%
sns.set(rc={'figure.figsize': (20, 10)})
sns.barplot(x=occupation_count.index, y=occupation_count.values)
plt.title('Bar graph showing the value counts of the column - Occupation', fontsize=16)
plt.ylabel('Count', fontsize=14)
plt.xlabel('Occupation', fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %%
# Explore data balance
label = df_cleaned.Credit_Score.value_counts().index
label_count = df_cleaned.Credit_Score.value_counts().values
plt.pie(data=df_cleaned, x=label_count, labels=label, autopct='%1.1f%%', shadow=True, radius=1)
plt.show()

# %%
df_cleaned.hist(figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Annual_Income'}>,
#         <AxesSubplot:title={'center':'Delay_from_due_date'}>],
#        [<AxesSubplot:title={'center':'Num_of_Delayed_Payment'}>,
#         <AxesSubplot:title={'center':'Outstanding_Debt'}>,
#         <AxesSubplot:title={'center':'Credit_History_Age'}>],
#        [<AxesSubplot:title={'center':'Payment_of_Min_Amount'}>,
#         <AxesSubplot:title={'center':'Total_EMI_per_month'}>,
#         <AxesSubplot:title={'center':'Payment_Behaviour'}>],
#        [<AxesSubplot:title={'center':'Monthly_Balance'}>,
#         <AxesSubplot:title={'center':'Credit_Score'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
col_float = ['Age','Annual_Income','Delay_from_due_date','Num_of_Delayed_Payment',
             'Outstanding_Debt','Credit_History_Age','Total_EMI_per_month','Monthly_Balance']
for i in df_cleaned[col_float]:
  df_cleaned[i] = scaler.fit_transform(df_cleaned[[i]])
df_cleaned.head()
# Out:
#    Age Occupation  Annual_Income  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0 0.06  Scientist           0.08                 0.11                    0.00
# 2 0.00  Scientist           0.08                 0.11                    0.00
# 3 0.06  Scientist           0.08                 0.14                    0.00
# 6 0.06  Scientist           0.08                 0.11                    0.00
# 9 0.06    Teacher           0.19                 0.17                    0.00
#
#    Outstanding_Debt  Credit_History_Age  Payment_of_Min_Amount  \
# 0              0.16                0.65                      2
# 2              0.16                0.66                      2
# 3              0.16                0.66                      2
# 6              0.16                0.67                      2
# 9              0.12                0.79                      2
#
#    Total_EMI_per_month  Payment_Behaviour  Monthly_Balance  Credit_Score
# 0                 0.00               4.00             1.00             3
# 2                 0.00               2.00             1.00             3
# 3                 0.00               1.00             1.00             3
# 6                 0.00               1.00             1.00             3
# 9                 0.00               6.00             1.00             3

# %%
#encoding
df_cleaned.columns
# Out:
# Index(['Age', 'Occupation', 'Annual_Income', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Outstanding_Debt', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month', 'Payment_Behaviour',
#        'Monthly_Balance', 'Credit_Score'],
#       dtype='object')

# %%
df_cleaned = pd.get_dummies(df_cleaned, prefix='Occupation', columns=['Occupation'], drop_first=False)
df_cleaned.head()
# Out:
#    Age  Annual_Income  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0 0.06           0.08                 0.11                    0.00
# 2 0.00           0.08                 0.11                    0.00
# 3 0.06           0.08                 0.14                    0.00
# 6 0.06           0.08                 0.11                    0.00
# 9 0.06           0.19                 0.17                    0.00
#
#    Outstanding_Debt  Credit_History_Age  Payment_of_Min_Amount  \
# 0              0.16                0.65                      2
# 2              0.16                0.66                      2
# 3              0.16                0.66                      2
# 6              0.16                0.67                      2
# 9              0.12                0.79                      2
#
#    Total_EMI_per_month  Payment_Behaviour  Monthly_Balance  ...  \
# 0                 0.00               4.00             1.00  ...
# 2                 0.00               2.00             1.00  ...
# 3                 0.00               1.00             1.00  ...
# 6                 0.00               1.00             1.00  ...
# 9                 0.00               6.00             1.00  ...
#
#    Occupation_Entrepreneur  Occupation_Journalist  Occupation_Lawyer  \
# 0                        0                      0                  0
# 2                        0                      0                  0
# 3                        0                      0                  0
# 6                        0                      0                  0
# 9                        0                      0                  0
#
#    Occupation_Manager  Occupation_Mechanic  Occupation_Media_Manager  \
# 0                   0                    0                         0
# 2                   0                    0                         0
# 3                   0                    0                         0
# 6                   0                    0                         0
# 9                   0                    0                         0
#
#    Occupation_Musician  Occupation_Scientist  Occupation_Teacher  \
# 0                    0                     1                   0
# 2                    0                     1                   0
# 3                    0                     1                   0
# 6                    0                     1                   0
# 9                    0                     0                   1
#
#    Occupation_Writer
# 0                  0
# 2                  0
# 3                  0
# 6                  0
# 9                  0
#
# [5 rows x 26 columns]

# %%
X = df_cleaned.drop('Credit_Score',axis = 1)
y = df_cleaned['Credit_Score']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
### Apply SelectKBest Algorithm
ordered_rank_features=SelectKBest(score_func=chi2,k=15)
ordered_feature=ordered_rank_features.fit(X,y)

# %%
dfscores=pd.DataFrame(ordered_feature.scores_,columns=["Score"])
dfcolumns=pd.DataFrame(X.columns)

# %%
features_rank=pd.concat([dfcolumns,dfscores],axis=1)

# %%
features_rank.columns=['Features','Score']
features_rank
# Out:
#                     Features   Score
# 0                        Age    0.18
# 1              Annual_Income  544.65
# 2        Delay_from_due_date 1511.79
# 3     Num_of_Delayed_Payment    1.96
# 4           Outstanding_Debt 1984.02
# 5         Credit_History_Age 1177.31
# 6      Payment_of_Min_Amount 2209.90
# 7        Total_EMI_per_month    1.49
# 8          Payment_Behaviour 1013.42
# 9            Monthly_Balance    0.00
# 10     Occupation_Accountant    5.39
# 11      Occupation_Architect    4.40
# 12      Occupation_Developer    0.19
# 13         Occupation_Doctor    7.77
# 14       Occupation_Engineer    5.23
# 15   Occupation_Entrepreneur    5.06
# 16     Occupation_Journalist    7.79
# 17         Occupation_Lawyer    6.50
# 18        Occupation_Manager    5.47
# 19       Occupation_Mechanic    8.54
# 20  Occupation_Media_Manager    6.31
# 21       Occupation_Musician    3.42
# 22      Occupation_Scientist    1.15
# 23        Occupation_Teacher   10.51
# 24         Occupation_Writer   52.24

# %%
features_rank.nlargest(10,'Score')
# Out:
#                  Features   Score
# 6   Payment_of_Min_Amount 2209.90
# 4        Outstanding_Debt 1984.02
# 2     Delay_from_due_date 1511.79
# 5      Credit_History_Age 1177.31
# 8       Payment_Behaviour 1013.42
# 1           Annual_Income  544.65
# 24      Occupation_Writer   52.24
# 23     Occupation_Teacher   10.51
# 19    Occupation_Mechanic    8.54
# 16  Occupation_Journalist    7.79

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model=ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [8.62294199e-02 9.83562590e-02 1.32692985e-01 9.67809070e-02
#  1.61114070e-01 1.59597625e-01 5.64573779e-02 7.96645618e-02
#  4.95084554e-02 6.57529677e-05 5.11296871e-03 5.36271468e-03
#  5.83574707e-03 4.98871037e-03 5.55671779e-03 5.23741152e-03
#  5.42411337e-03 5.56654755e-03 5.87404049e-03 4.91595547e-03
#  5.52646624e-03 5.92738465e-03 5.84652302e-03 4.40896715e-03
#  3.94831838e-03]

# %%
ranked_features=pd.Series(model.feature_importances_,index=X.columns)
lst=ranked_features.nlargest(10).plot(kind='barh')
plt.show()
lst=ranked_features.nlargest(6)
print(lst)
# Out:
# Outstanding_Debt         0.16
# Credit_History_Age       0.16
# Delay_from_due_date      0.13
# Annual_Income            0.10
# Num_of_Delayed_Payment   0.10
# Age                      0.09
# dtype: float64

# %%
import seaborn as sns
corr=df_cleaned.iloc[:,:-1].corr()
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df_cleaned[top_features].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
threshold=0.5

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
col_corr = correlation(X,threshold)

# %%
#df_cleaned = df_cleaned[['Credit_History_Age', 'Outstanding_Debt','Payment_Behaviour','Annual_Income','Delay_from_due_date','Num_of_Delayed_Payment','Credit_Score']]
df_cleaned = df_cleaned[['Credit_History_Age', 'Outstanding_Debt','Credit_Score']]
df_cleaned.head()
# Out:
#    Credit_History_Age  Outstanding_Debt  Credit_Score
# 0                0.65              0.16             3
# 2                0.66              0.16             3
# 3                0.66              0.16             3
# 6                0.67              0.16             3
# 9                0.79              0.12             3

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_cleaned.drop('Credit_Score',axis=1))
scaled_features
# Out:
# array([[ 0.46028366, -0.54071491],
#        [ 0.48439632, -0.54071491],
#        [ 0.49645265, -0.54071491],
#        ...,
#        [ 1.60563513, -0.80690871],
#        [ 1.61769146, -0.80690871],
#        [ 1.6297478 , -0.80690871]])

# %%
#### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(scaled_features, df_cleaned['Credit_Score'],test_size=0.20,random_state=None)

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in c:\users\admin\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (1.1.0)
# Requirement already satisfied: lightgbm in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (3.3.5)
# Requirement already satisfied: xgboost in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (1.7.4)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: click in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (from lazypredict) (1.4.4)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click->lazypredict) (0.4.5)
# Requirement already satisfied: wheel in c:\users\admin\anaconda3\lib\site-packages (from lightgbm->lazypredict) (0.37.1)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from lightgbm->lazypredict) (1.9.1)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from lightgbm->lazypredict) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->lazypredict) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->lazypredict) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [03:23<00:00,  7.00s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# BaggingClassifier                  0.75               0.72    None      0.75
# DecisionTreeClassifier             0.73               0.72    None      0.73
# ExtraTreeClassifier                0.61               0.58    None      0.61
# NearestCentroid                    0.48               0.56    None      0.47
# ExtraTreesClassifier               0.61               0.56    None      0.61
# RandomForestClassifier             0.59               0.53    None      0.59
# KNeighborsClassifier               0.61               0.53    None      0.59
# PassiveAggressiveClassifier        0.52               0.52    None      0.51
# LGBMClassifier                     0.62               0.48    None      0.57
# GaussianNB                         0.52               0.47    None      0.52
# BernoulliNB                        0.60               0.47    None      0.54
# SVC                                0.61               0.45    None      0.54
# AdaBoostClassifier                 0.61               0.45    None      0.54
# SGDClassifier                      0.57               0.43    None      0.51
# QuadraticDiscriminantAnalysis      0.54               0.40    None      0.48
# LinearDiscriminantAnalysis         0.54               0.39    None      0.47
# LogisticRegression                 0.54               0.38    None      0.46
# RidgeClassifier                    0.54               0.38    None      0.46
# LinearSVC                          0.54               0.38    None      0.46
# CalibratedClassifierCV             0.54               0.38    None      0.46
# RidgeClassifierCV                  0.54               0.38    None      0.46
# Perceptron                         0.53               0.33    None      0.37
# DummyClassifier                    0.53               0.33    None      0.37
#
#                                Time Taken
# Model
# BaggingClassifier                    1.02
# DecisionTreeClassifier               0.20
# ExtraTreeClassifier                  0.06
# NearestCentroid                      0.05
# ExtraTreesClassifier                 4.13
# RandomForestClassifier               6.48
# KNeighborsClassifier                 0.29
# PassiveAggressiveClassifier          0.14
# LGBMClassifier                       0.44
# GaussianNB                           0.06
# BernoulliNB                          0.05
# SVC                                179.15
# AdaBoostClassifier                   1.05
# SGDClassifier                        0.25
# QuadraticDiscriminantAnalysis        0.05
# LinearDiscriminantAnalysis           0.05
# LogisticRegression                   0.28
# RidgeClassifier                      0.08
# LinearSVC                            2.76
# CalibratedClassifierCV               6.07
# RidgeClassifierCV                    0.12
# Perceptron                           0.17
# DummyClassifier                      0.03

# %%
score_dict = []

# %%
#k-fold cross validation
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5,random_state= None)
k = kfold.get_n_splits(scaled_features)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn_classifier=KNeighborsClassifier(n_neighbors= k).fit(X_train,y_train)
prediction=knn_classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_curve, roc_auc_score
print(f'confusion matrix : {confusion_matrix(y_test,prediction)}')
print(f'Accuracy Score : {accuracy_score(y_test,prediction)}')
print(classification_report(y_test,prediction))
score_dict.append(accuracy_score(y_test,prediction))
# Out:
# confusion matrix : [[2613 1437  125]
#  [1484 5312  622]
#  [ 243 1570  562]]
# Accuracy Score : 0.6076030927835051
#               precision    recall  f1-score   support
#
#            1       0.60      0.63      0.61      4175
#            2       0.64      0.72      0.68      7418
#            3       0.43      0.24      0.31      2375
#
#     accuracy                           0.61     13968
#    macro avg       0.56      0.53      0.53     13968
# weighted avg       0.59      0.61      0.59     13968

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr = lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
count_true = 0
lst_predict = []
lst_test= []
for k,y_predict in enumerate(y_pred):
    lst_predict.append(y_predict)
for k,y_predict1 in enumerate(y_test):
    lst_test.append(y_predict1)
for j, y_predict  in enumerate(lst_predict):
    if (abs(lst_predict[j]- lst_test[j]) < 1):
        count_true += 1
score_dict.append(count_true/len(y_test))

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(random_state=2)
dtree = dtree.fit(X_train, y_train)

y_pred = dtree.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
accuracy = accuracy_score(y_test,y_pred)
print("accuracy=",accuracy)
score_dict.append(accuracy_score(y_test,y_pred))
# Out:
# accuracy= 0.7331042382588774

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_train, y_train)
y_pred = gnb.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
accuracy = accuracy_score(y_test,y_pred)
print("confusion matrics=",cm)
print("accuracy=",accuracy)
score_dict.append(accuracy_score(y_test,y_pred))
# Out:
# confusion matrics= [[1960 1888  327]
#  [1399 4508 1511]
#  [  63 1518  794]]
# accuracy= 0.5199026345933563

# %%
### Manual Hyperparameter Tuning
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=300,criterion='entropy',
                             max_features='sqrt',min_samples_leaf=10,random_state=100).fit(X_train,y_train)
predictions=model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(accuracy_score(y_test,predictions))
print(classification_report(y_test,predictions))
score_dict.append(accuracy_score(y_test,predictions))
# Out:
# [[2619 1490   66]
#  [1185 6022  211]
#  [  47 2011  317]]
# 0.6413230240549829
#               precision    recall  f1-score   support
#
#            1       0.68      0.63      0.65      4175
#            2       0.63      0.81      0.71      7418
#            3       0.53      0.13      0.21      2375
#
#     accuracy                           0.64     13968
#    macro avg       0.62      0.52      0.53     13968
# weighted avg       0.63      0.64      0.61     13968

# %%
score_dict
# Out:
# [0.6076030927835051,
#  0.9017038946162658,
#  0.7331042382588774,
#  0.5199026345933563,
#  0.6413230240549829]

# %%
score_dict = sorted(score_dict)
score_dict
# Out:
# [0.5199026345933563,
#  0.6076030927835051,
#  0.6413230240549829,
#  0.7331042382588774,
#  0.9017038946162658]

# %%
fig, ax = plt.subplots(figsize=(20, 6))
ax.bar(np.arange(len(score_dict)) - 0.2, score_dict, color='r', width=0.25, align='center')
ax.legend(["Accuracy"])
ax.set_xticklabels(score_dict)
ax.set_xticks(np.arange(len(score_dict)))
plt.ylabel("Accuracy")
plt.show()
